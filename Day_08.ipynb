# %% [markdown]
# <a href="https://colab.research.google.com/github/TapanPatra/automate_with_python/blob/main/Day_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Define Function**

# %%
def hello():
  print("Hello, World!")

# %% [markdown]
# # **Calling Function**

# %%
hello()
# Out:
# Hello, World!

# %% [markdown]
# # **Function with Parameters /Params**

# %%
def hello(name):
  print("Hello, " + name + "!")

# %%
hello("Tapan")
# Out:
# Hello, Tapan!

# %% [markdown]
# # **F String**

# %%
country = "India"
capital = "New Delhi"
print(f"{capital}, is capital of {country}")
# Out:
# New Delhi, is capital of India

# %% [markdown]
# # **Function return something**

# %%
def sum(a,b):
  return (a+b)

# %%
sum(5, 10)
# Out:
# 15

# %%
result = sum(5, 10)
result
# Out:
# 15
