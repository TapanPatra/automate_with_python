# %% [markdown]
# <a href="https://colab.research.google.com/github/TapanPatra/automate_with_python/blob/main/Day_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ticket_price =90
wallet_size =100

# %%
if ticket_price <= wallet_size:
  print("Hurray!, I can go to movie")
else:
  print("Sad!, I don't have enough money")
# Out:
# Hurray!, I can go to movie

# %%
# ctrl+ Enter - run code

# %%
marks = 85

if marks >= 90:
  print("A+")
elif marks >= 80:
  print("A")
elif marks >= 70 :
  print("B+")
elif marks >= 60:
  print("B")
else:
  print("Fail")
# Out:
# A

# %% [markdown]
# ### Exercise: Check if a number is positive or negative
#
# Write a Python program that takes a number as input and checks if it's positive, negative, or zero using an `if-elif-else` statement. Print an appropriate message for each case.

# %%
# You can try with different values for the 'number' variable
number = -5 # Try changing this value to a positive number or zero

# Write your if-elif-else statement below this line

# %%
number = -5
if number > 0:
  print("Positive")
elif number < 0:
  print("Negative")
else:
  print("Zero")
# Out:
# Negative
