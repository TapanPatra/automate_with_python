# %% [markdown]
# <a href="https://colab.research.google.com/github/TapanPatra/automate_with_python/blob/main/Day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables

# %%
# str - string
# int - integer
# float - decimal

# %%
# comment - ctrl + /

# %%
rohit = 50
virat = 70
rahul = 40

# %%
virat
# Out:
# 70

# %%
totalScore = virat + rohit + rahul

# %%
totalScore
# Out:
# 160

# %%
5+2
# Out:
# 7

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
5*2
# Out:
# 10

# %%
5-2
# Out:
# 3
