# %% [markdown]
# <a href="https://colab.research.google.com/github/TapanPatra/automate_with_python/blob/main/Day06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Quiz on List**

# %% [markdown]
# ### **Python List Quiz**
#
# Test your knowledge of Python lists with the following questions!

# %%
# Question 1: How do you create an empty list?
# a) list = {}
# b) list = []
# c) list = ()
# d) list = ''

# Question 2: How do you add the element 'apple' to the end of a list called 'fruits'?
# a) fruits.add('apple')
# b) fruits.insert('apple')
# c) fruits.append('apple')
# d) fruits.extend('apple')

# Question 3: What is the index of the element 'banana' in the list `my_list = ['apple', 'banana', 'cherry']`?
# a) 0
# b) 1
# c) 2
# d) 3

# Question 4: How do you remove the element 'cherry' from the list `my_list = ['apple', 'banana', 'cherry']`?
# a) my_list.remove('cherry')
# b) del my_list[2]
# c) my_list.pop(2)
# d) All of the above

# Question 5: What will be the output of `len(['a', 'b', 'c', 'd'])`?
# a) 3
# b) 4
# c) 5
# d) Error


# Solutions (uncomment to reveal):
# print("\n--- Solutions ---")
# print("1. b) list = []")
# print("2. c) fruits.append('apple')")
# print("3. b) 1")
# print("4. d) All of the above")
# print("5. b) 4")
