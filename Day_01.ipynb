# %% [markdown]
# <a href="https://colab.research.google.com/github/TapanPatra/automate_with_python/blob/main/Day_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!
