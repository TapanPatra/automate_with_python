# %% [markdown]
# <a href="https://colab.research.google.com/github/TapanPatra/automate_with_python/blob/main/Day_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Creating List**

# %%
items =[]

# %%
items = ["Apple", "Orange", "Banana", "Mango"]

# %% [markdown]
# # **Accessing Elements**

# %%
items[0]
# Out:
# 'Apple'

# %%
items[2]
# Out:
# 'Banana'

# %% [markdown]
# # **Negative Index in List**

# %%
items[-1]
# Out:
# 'Mango'

# %%
items[-2]
# Out:
# 'Banana'

# %% [markdown]
# #**Modify List**

# %%
items[2]= "Grapes"
items
# Out:
# ['Apple', 'Orange', 'Grapes', 'Mango']

# %% [markdown]
# #**Add Elements to List**

# %%
items.append("Guava")
items.append("Watermelon")

# %%
items
# Out:
# ['Apple', 'Orange', 'Grapes', 'Mango', 'Guava', 'Watermelon']

# %% [markdown]
# # **Slicing List**

# %%
items[0:3]
# Out:
# ['Apple', 'Orange', 'Grapes']

# %%
items[2:]
# Out:
# ['Grapes', 'Mango', 'Guava', 'Watermelon']

# %%
items[:3]
# Out:
# ['Apple', 'Orange', 'Grapes']

# %%
items[2:-1]
# Out:
# ['Grapes', 'Mango', 'Guava']

# %%
items[0:-2]
# Out:
# ['Apple', 'Orange', 'Grapes', 'Mango']

# %% [markdown]
# # **Remove Element in List**

# %%
items
# Out:
# ['Apple', 'Orange', 'Grapes', 'Mango', 'Guava', 'Watermelon']

# %%
items.remove("Guava")
items
# Out:
# ['Apple', 'Orange', 'Grapes', 'Mango', 'Watermelon']

# %%
del items[0]
items
# Out:
# ['Orange', 'Grapes', 'Mango', 'Watermelon']

# %%
items.clear()
items
# Out:
# []

# %%
items = ["Apple", "Orange", "Banana", "Mango"]
items
# Out:
# ['Apple', 'Orange', 'Banana', 'Mango']

# %% [markdown]
# # **Checking for Existence**

# %%
"Apple" in items
# Out:
# True

# %% [markdown]
# # **Length of List**

# %%
len(items)
# Out:
# 4

# %% [markdown]
# # **List Comprehension**

# %%
numbers = [10, 20, 30, 40]
for i in numbers:
  print(i/2)
# Out:
# 5.0
# 10.0
# 15.0
# 20.0

# %%
[i/2 for i in numbers]
# Out:
# [5.0, 10.0, 15.0, 20.0]
